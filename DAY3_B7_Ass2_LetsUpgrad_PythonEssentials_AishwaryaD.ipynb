# %% [markdown]
# # Day 3 Assignment 1 Q1

# %%
#You all are pilots, you want to land a plane safely, so ask the pilot to take current altitude as input and check whether the altitude
#in less than 1000ft to land plane or more than 1000ft and if it is less than 5000ft ask pilot to bring down the pane it further
#down to 1000ft and it is more than 5000ft then ask pilot to turn around and try later.

num = input("Enter the current altitude : ")
num = int(num)
if num <= 1000:
    print("Land the plane")
elif num > 1000 or num <=5000:
    print("Bring down to 1000ft")
else:
    if num>5000:
        print("Go around and try later")
    else:
        pass
# Out:
# Enter the current altitude : 5000
# Bring down to 1000ft

# %% [markdown]
# # Q2

# %%
#Using for loop print all the prime numbers between 1-200 using for loop and RANGE function.

# %%
a=1
b=200
for num in range(a,b):
    if(num>1):
        for i in range(2,num):
            if(num%i==0):
                break
            else:
                print(num)
# Out:
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 11
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 15
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 17
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 19
# 21
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 25
# 25
# 25
# 27
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 29
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 31
# 33
# 35
# 35
# 35
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 37
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# ...
